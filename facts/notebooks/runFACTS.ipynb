# %% [markdown]
# ## Configure FACTS run

# %%
# Configure directories and experiment

#factsdir = '/opt/facts' # FACTS root directory
factsdir = '/explore/nobackup/projects/ilab/projects/sealevel/facts'
exp_name = 'coupling.ssp585' # desired experiment name


experiment_config = """
global-options:
    nsamps: 2000
    scenario: ssp585
    pyear_start: 2020
    pyear_end: 2150
    pyear_step: 10
    baseyear: 2005

# climate_step:
#     temperature:
#         module_set: "fair"
#         module: "temperature"
#         generates_climate_output: true
# #        input_data_file:
# #              - "emissions.csv"
# #        options:
# #              rcmip_file: emissions.csv

sealevel_step:
    GrIS1f:
        module_set: "FittedISMIP"
        module: "GrIS"
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"

    deconto21:
        module_set: "deconto21"
        module: "AIS"
        include_in_workflow:
            - "wf3e"   
            - "wf3f"

    bamber19:
        module_set: "bamber19"
        module: "icesheets"
        include_in_workflow:
            - "wf4" 

    emuAIS:
        module_set: "emulandice"
        module: "AIS"
        include_in_workflow:
            - "wf1e"      
        options:
            pyear_end: 2100

    emuGrIS:
        module_set: "emulandice"
        module: "GrIS"
        include_in_workflow:
            - "wf1e"  
            - "wf2e"  
            - "wf3e"  
        options:
            pyear_end: 2100

    emuglaciers:
        module_set: "emulandice"
        module: "glaciers"
        include_in_workflow:
            - "wf1e"   
            - "wf2e"   
            - "wf3e"
        options:
            pyear_end: 2100

    larmip:
        module_set: "larmip"
        module: "AIS"
        include_in_workflow:
            - "wf2e"
            - "wf2f"

    ar5glaciers:
        module_set: "ipccar5"
        module: "glaciers"
        options:
            gmip: 2
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"
            - "wf4"

    ar5AIS:
        module_set: "ipccar5"
        module: "icesheets"
        pipeline_file: "pipeline.AIS.yml"
        include_in_workflow:
            - "wf1f"

    ocean:
        module_set: "tlm"
        module: "sterodynamics"
        include_in_workflow:
            - "wf1f"
            - "wf1e"
            - "wf2e"
            - "wf2f"
            - "wf3e"
            - "wf3f"
            - "wf4"

    k14vlm:
        module_set: "kopp14"
        module: "verticallandmotion"
        include_in_workflow:
            - "wf1f"
            - "wf1e"
            - "wf2e"
            - "wf2f"
            - "wf3e"
            - "wf3f"
            - "wf4"

    lws:
        module_set: "ssp"
        module: "landwaterstorage"
        options:
            scenario: "ssp5"
            dcrate_lo: -0.4
        include_in_workflow:
            - "wf1f"
            - "wf1e"
            - "wf2e"
            - "wf2f"
            - "wf3e"
            - "wf3f"
            - "wf4"

totaling_step:
    total:
        module_set: "facts"
        module: "total"
        loop_over_workflows: true
        loop_over_scales: true
        stages:
            - workflow

esl_step:
    extremesealevel:
        loop_over_workflows: true
        module_set: "extremesealevel"
        module: "pointsoverthreshold"
        options:
            target_years: 2050,2100
            total_localsl_file: "$SHARED/totaled/%EXPERIMENT_NAME%.total.workflow.%WORKFLOW_NAME%.local.nc" 
"""

_experiment_config = """
global-options:
    nsamps: 200
    scenario: ssp245
    pyear_start: 2020
    pyear_end: 2150
    pyear_step: 10
    baseyear: 2005
    pipeline_file: 'pipeline.global.yml'

climate_step:
    temperature:
        module_set: "fair"
        module: "temperature"
        generates_climate_output: true

sealevel_step:
    GrIS1f:
        module_set: "FittedISMIP"
        module: "GrIS"
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"

    deconto21:
        module_set: "deconto21"
        module: "AIS"
        include_in_workflow:
            - "wf3f"

    bamber19:
        module_set: "bamber19"
        module: "icesheets"
        include_in_workflow:
            - "wf4"

    larmip:
        module_set: "larmip"
        module: "AIS"
        include_in_workflow:
            - "wf2f"

    ar5glaciers:
        module_set: "ipccar5"
        module: "glaciers"
        options:
            gmip: 2
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"
            - "wf4"

    ar5AIS:
        module_set: "ipccar5"
        module: "icesheets"
        pipeline_file: "pipeline.AIS.global.yml"
        include_in_workflow:
            - "wf1f"

    ocean:
        module_set: "tlm"
        module: "sterodynamics"
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"
            - "wf4"

    lws:
        module_set: "ssp"
        module: "landwaterstorage"
        options:
            scenario: "ssp2"
            dcrate_lo: -0.4
        include_in_workflow:
            - "wf1f"
            - "wf2f"
            - "wf3f"
            - "wf4"


totaling_step:
    total:
        module_set: "facts"
        module: "total"
        loop_over_workflows: true
        loop_over_scales: true
        stages:
            - workflow

"""

# %% [markdown]
# Write the experiment `config.yml` file.

# %%
import sys
# Add a path to the search list
sys.path.insert(0, '/explore/nobackup/projects/ilab/projects/sealevel/facts')

# %%
#!pip install radical-asyncflow

# %%
import os 
import sys

os.chdir(factsdir)
import runFACTS

exp_dir=os.path.join(factsdir,'experiments',exp_name)
resourcedir=os.path.join(factsdir,'resources')
try:
    os.makedirs(exp_dir)
except:
    None

f = open(os.path.join(exp_dir,'config.yml'),'w')
print(exp_dir, '\n', resourcedir, '\n', f)
f.write(experiment_config)
f.close()
# Out:
# /explore/nobackup/projects/ilab/projects/sealevel/facts/experiments/coupling.ssp585
#  /explore/nobackup/projects/ilab/projects/sealevel/facts/resources
#  <_io.TextIOWrapper name='/explore/nobackup/projects/ilab/projects/sealevel/facts/experiments/coupling.ssp585/config.yml' mode='w' encoding='UTF-8'>

# %%
# !cd /explore/nobackup/projects/ilab/projects/sealevel/facts
# !pwd
# Out:
# /panfs/ccds02/nobackup/projects/ilab/projects/sealevel/facts

# %% [markdown]
# ## Run FACTS
#
# Run the newly created FACTS experiment.

# %%
runFACTS.run_experiment(exp_dir,resourcedir=resourcedir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 runFACTS.run_experiment(exp_dir,resourcedir=resourcedir)
#
# File /explore/nobackup/projects/ilab/projects/sealevel/facts/runFACTS.py:19, in run_experiment(exp_dir, debug_mode, alt_id, resourcedir, makeshellscript, globalopts)
#      16 if not resourcedir:
#      17     resourcedir = exp_dir
# ---> 19 expconfig = facts.ParseExperimentConfig(exp_dir, globalopts=globalopts)
#      20 experimentsteps = expconfig['experimentsteps']
#      21 workflows = expconfig['workflows']
#
# File /explore/nobackup/projects/ilab/projects/sealevel/facts/FACTS.py:480, in ParseExperimentConfig(exp_dir, globalopts)
#     478         pipelines.append(GeneratePipeline(parsed['pcfg'], parsed['modcfg'], parsed['pipe_name'] + "." + this_workflow, exp_dir, workflow_name=this_workflow))
#     479 else:
# --> 480     pipelines.append(GeneratePipeline(parsed['pcfg'], parsed['modcfg'], parsed['pipe_name'], exp_dir))
#     482 if "include_in_workflow" in ecfg[this_mod][this_mod_sub].keys():
#     483     outfiles = IdentifyOutputFiles(parsed['pcfg'], parsed['pipe_name'])
#
# File /explore/nobackup/projects/ilab/projects/sealevel/facts/FACTS.py:58, in GeneratePipeline(pcfg, ecfg, pipe_name, exp_dir, stage_names, workflow_name, scale_name)
#      54 for this_stage in stage_names:
#      55     if this_stage in pcfg.keys():
#      56
#      57         # Populate the pipeline with the stages
# ---> 58         p.add_stages(GenerateStage(pcfg[this_stage], ecfg, p.name, this_stage, workflow_name=workflow_name, scale_name=scale_name))
#      60 return(p)
#
# File /explore/nobackup/projects/ilab/projects/sealevel/facts/FACTS.py:75, in GenerateStage(scfg, ecfg, pipe_name, stage_name, workflow_name, scale_name)
#      71 # Loop through the tasks for this stage
#      72 for this_task in scfg.keys():
#      73
#      74     # Populate the stage object with the tasks
# ---> 75     s.add_tasks(GenerateTask(scfg[this_task], ecfg, pipe_name, stage_name, this_task, workflow_name=workflow_name, scale_name=scale_name))
#      77 # Return the stage object
#      78 return(s)
#
# File /explore/nobackup/projects/ilab/projects/sealevel/facts/FACTS.py:162, in GenerateTask(tcfg, ecfg, pipe_name, stage_name, task_name, workflow_name, scale_name)
#     160     this_file = os.path.join('.','modules-data', this_file)
#     161 if not os.path.isfile(this_file):
# --> 162     raise(FileNotFoundError(pipe_name + "." + stage_name + ": upload_and_extract_input_data: " + this_file + " not found!"))
#     163 t.pre_exec.append('tar -xvf ' + os.path.basename(this_file) + ' 2> /dev/null; rm ' + os.path.basename(this_file))
#     164 t.upload_input_data.append(this_file)
#
# FileNotFoundError: coupling.ssp585.GrIS1f.FittedISMIP.GrIS.fit: upload_and_extract_input_data: ./modules-data/FittedISMIP_icesheet_fit_data.tgz not found!

# %% [markdown]
# ## Visualize output

# %%
os.listdir(os.path.join(exp_dir,'output'))

# %%
import xarray as xr

datafile='jupyter01.total.workflow.wf4.global.nc'
ds = xr.open_dataset(os.path.join(exp_dir,'output',datafile))

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(ds.years,ds.sea_level_change.quantile(.5,dim='samples'))
plt.plot(ds.years,ds.sea_level_change.quantile(.17,dim='samples'))
plt.plot(ds.years,ds.sea_level_change.quantile(.83,dim='samples'))

plt.ylabel('mm')
plt.title(datafile)

# %%
dq=ds.sea_level_change.quantile([.17,.5,.83],dim='samples')
u=dq[:,:,0]
print(u.to_pandas())
