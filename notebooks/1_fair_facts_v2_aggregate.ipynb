# %% [markdown]
# fair_facts_v2:
#
# The Framework for Assessing Changes To Sea-level (FACTS) is an open-source modular, scalable, and extensive framework for global mean, regional, and extreme sea level projection that is designed to support the characterization of ambiguity in sea-level projections. It is designed so users can easily explore deep uncertainty by investigating the implications on GMSL, RSL, and ESL of different choices for different processes. Its modularity allows components to be represented by either simple or complex model. Because it is built upon the Radical-PILOT computing stack, different modules can be dispatched for execution on resources appropriate to their computational complexity.
#
# FACTS is being developed by the Earth System Science & Policy Lab and the RADICAL Research Group at Rutgers University. FACTS is released under the MIT License.
#
# Project Github Page: https://github.com/radical-collaboration/facts

# %%
# !pip install radical-asyncflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: radical-asyncflow in /home/gtamkin/.local/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: pydantic in /home/gtamkin/.local/lib/python3.11/site-packages (from radical-asyncflow) (2.12.5)
# Requirement already satisfied: typeguard in /home/gtamkin/.local/lib/python3.11/site-packages (from radical-asyncflow) (4.4.4)
# Requirement already satisfied: requests in /usr/local/other/anaconda/GEOSpyD/24.3.0-0/2024-08-29/envs/py3.12/envs/viz/lib/python3.11/site-packages (from radical-asyncflow) (2.32.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/gtamkin/.local/lib/python3.11/site-packages (from pydantic->radical-asyncflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/gtamkin/.local/lib/python3.11/site-packages (from pydantic->radical-asyncflow) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/gtamkin/.local/lib/python3.11/site-packages (from pydantic->radical-asyncflow) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/gtamkin/.local/lib/python3.11/site-packages (from pydantic->radical-asyncflow) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/other/anaconda/GEOSpyD/24.3.0-0/2024-08-29/envs/py3.12/envs/viz/lib/python3.11/site-packages (from requests->radical-asyncflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/other/anaconda/GEOSpyD/24.3.0-0/2024-08-29/envs/py3.12/envs/viz/lib/python3.11/site-packages (from requests->radical-asyncflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/other/anaconda/GEOSpyD/24.3.0-0/2024-08-29/envs/py3.12/envs/viz/lib/python3.11/site-packages (from requests->radical-asyncflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/other/anaconda/GEOSpyD/24.3.0-0/2024-08-29/envs/py3.12/envs/viz/lib/python3.11/site-packages (from requests->radical-asyncflow) (2025.7.14)

# %%
import asyncio
import logging
import time
import os
import shlex
import random

from radical.asyncflow import WorkflowEngine
from radical.asyncflow import ConcurrentExecutionBackend

from concurrent.futures import ThreadPoolExecutor

from radical.asyncflow.logging import init_default_logger

logger = logging.getLogger(__name__)

# %%
async def modules():
    init_default_logger(logging.DEBUG)

    # Create backend and workflow
    engine = await ConcurrentExecutionBackend(ThreadPoolExecutor())
    flow = await WorkflowEngine.create(engine)
    
    # Ensure output directories exist
    def setup_directories():
        os.makedirs('./data/output/fair', exist_ok=True)
        os.makedirs('./data/output/lws', exist_ok=True)
        os.makedirs('./data/output/sterodynamics', exist_ok=True)

    @flow.executable_task
    async def fair_task():
        """FAIR temperature model task"""
        cmd = [
            '/usr/local/other/singularity/4.0.3/bin/singularity', 'exec',
            '--bind', '/discover/nobackup/projects/sealevel/facts2.0/data/input:/input',
            '--bind', './data/output/fair:/output',
            '/discover/nobackup/projects/sealevel/facts2.0//containers/fair-temperature.sif',
            'fair-temperature',
            '--pipeline-id=1234',
            '--output-oceantemp-file=/output/oceantemp.nc',
            '--nsamps=20',
            '--output-ohc-file=/output/ohc.nc',
            '--output-gsat-file=/output/gsat.nc',
            '--output-climate-file=/output/climate.nc',
            '--rcmip-file=/input/rcmip/rcmip-emissions-annual-means-v5-1-0.csv',
            '--param-file=/input/parameters/fair_ar6_climate_params_v4.0.nc'
        ]
        return shlex.join(cmd)

    @flow.executable_task
    async def lws_task():
        """Land Water Storage task - can run independently of FAIR"""
        cmd = [
            '/usr/local/other/singularity/4.0.3/bin/singularity', 'exec',
            '--bind', '/discover/nobackup/projects/sealevel/facts2.0/data/input:/input',
            '--bind', './data/output/lws:/output',
            '/discover/nobackup/projects/sealevel/facts2.0/containers/ssp-landwaterstorage.sif',
            'ssp-landwaterstorage',
            '--pipeline-id=1234',
            '--nsamps=20',
            '--output-gslr-file=/output/gslr.nc',
            '--output-lslr-file=/output/lslr.nc',
            '--location-file=/input/location.lst',
            '--pophist-file=/input/UNWPP2012 population historical.csv',
            '--reservoir-file=/input/Chao2008 groundwater impoundment.csv',
            '--popscen-file=/input/ssp_iam_baseline_popscenarios2100.csv',
            '--gwd-file=/input/Konikow2011 GWD.csv',
            '--gwd-file=/input/Wada2012 GWD.csv',
            '--gwd-file=/input/Pokhrel2012 GWD.csv',
            '--fp-file=/input/REL_GROUNDWATER_NOMASK.nc'
        ]
        return shlex.join(cmd)

    @flow.executable_task
    async def sterodynamics_task(fair_task):
        """Sterodynamics task - depends on FAIR output"""
        cmd = [
            '/usr/local/other/singularity/4.0.3/bin/singularity', 'exec',
            '--bind', '/discover/nobackup/projects/sealevel/facts2.0/data/input:/input',
            '--bind', './data/output/fair:/fair',
            '--bind', './data/output/sterodynamics:/output',
            '--nv',
            '/discover/nobackup/projects/sealevel/facts2.0/containers/tlm-sterodynamics.sif',
            'tlm-sterodynamics',
            '--pipeline-id=1234',
            '--scenario=ssp585',
            '--nsamps=20',
            '--model-dir=/input/cmip6/',
            '--location-file=/input/location.lst',
            '--output-lslr-file=/output/lslr.nc',
            '--output-gslr-file=/output/gslr.nc',
            '--expansion-coefficients-file=/input/scmpy2LM_RCMIP_CMIP6calpm_n18_expcoefs.nc',
            '--gsat-rmses-file=/input/scmpy2LM_RCMIP_CMIP6calpm_n17_gsat_rmse.nc',
            '--climate-data-file=/fair/climate.nc'
        ]
        return shlex.join(cmd)

    async def run_climate_workflow(pipeline_id):
        """Run the complete climate workflow"""
        logger.info(f'Starting climate workflow {pipeline_id} at {time.time()}')

        # Setup directories
        setup_directories()

        # Start FAIR and LWS tasks (they can run in parallel)
        fair_future = fair_task()
        lws_future = lws_task()

        # Wait for FAIR to complete (sterodynamics depends on it)
        fair_result = await fair_future
        logger.info(f'FAIR task completed for pipeline {pipeline_id}')

        # Start sterodynamics task (depends on FAIR output)
        sterodynamics_future = sterodynamics_task(fair_future)

        # Wait for all tasks to complete
        lws_result = await lws_future
        sterodynamics_result = await sterodynamics_future

        logger.info(f'Climate workflow {pipeline_id} finished at {time.time()}')

        return {
            'fair': fair_result,
            'lws': lws_result,
            'sterodynamics': sterodynamics_result
        }

    # Run workflow(s)
    transationId = random.randint(1, 1000)
    logger.info("Launching asynchronous workflow: "+str(transationId))
    results = await run_climate_workflow(transationId)
    logger.info("All modules completed successfully: "+str(transationId))
    
    await flow.shutdown()
    logger.info(results)
    logger.info("All workflows completed successfully")

# %%
import asyncio
import subprocess

from pathlib import Path

def file_exists_and_has_content(filepath):
    path = Path(filepath)
    return path.is_file() and path.stat().st_size > 0
    
async def total():
    init_default_logger(logging.DEBUG)

    # Create backend and workflow
    engine = await ConcurrentExecutionBackend(ThreadPoolExecutor())
    flow = await WorkflowEngine.create(engine)
    
    # Ensure output directories exist
    def setup_total_directories():
        os.makedirs('./data/output', exist_ok=True)

    @flow.executable_task
    async def total_task(component, name):
        """Facts total task - executes singularity command"""
        filename = ""
        if (component == 'all'):
            filename = '/mnt/total_out/totaled_output_all_'+name+'.nc'
            _filename = './data/output/totaled_output_all_'+name+'.nc'
            cmd = [
                '/usr/local/other/singularity/4.0.3/bin/singularity', 'exec',
                '--bind', './data/output:/mnt/total_in',
                '--bind', './data/output:/mnt/total_out',
                '/discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox',
                'facts-total',
                '--item=/mnt/total_out/lws/'+name+'.nc',
                '--item=/mnt/total_out/sterodynamics/'+name+'.nc',
                '--pyear-start=2020',
                '--pyear-end=2150',
                '--pyear-step=10',
                '--output-path='+filename
            ]
        else:
            filename = '/mnt/total_out/totaled_output_'+component+'_'+name+'.nc'
            _filename = './data/output/totaled_output_'+component+'_'+name+'.nc'
            cmd = [
                '/usr/local/other/singularity/4.0.3/bin/singularity', 'exec',
                '--bind', './data/output:/mnt/total_in',
                '--bind', './data/output:/mnt/total_out',
                '/discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox',
                'facts-total',
                '--item=/mnt/total_out/'+component+'/'+name+'.nc',
                '--pyear-start=2020',
                '--pyear-end=2150',
                '--pyear-step=10',
                '--output-path='+filename
            ]
        
        # Log the command
        cmd_str = shlex.join(cmd)
        logger.info(f"Executing: {cmd_str}")
        
        # RUN THE COMMAND ASYNCHRONOUSLY
        proc = await asyncio.create_subprocess_exec(
            *cmd,
            stdout=asyncio.subprocess.PIPE,
            stderr=asyncio.subprocess.PIPE
        )
        
        stdout, stderr = await proc.communicate()

        # Verify that file was created
        path = Path(_filename)
        if path.is_file() and path.stat().st_size > 0:
            logger.info(f"Output successfully created: {path}")
        else:            
            error_msg = f"Output unsuccessfully created: {path}"
            logger.error(f"Command failed with return code: {error_msg}")
            raise RuntimeError(f"Task failed: {error_msg}")
        
        logger.info(f"Command output: {stdout.decode()}")
        if stderr:
            logger.warning(f"Command stderr: {stderr.decode()}")
            
        return {
            'command': cmd_str,
            'component': component,
            'name': name,
            'returncode': proc.returncode
        }

    async def run_total_workflow(pipeline_id):
        """Run the total climate workflow"""
        logger.info(f'Starting total climate workflow {pipeline_id} at {time.time()}')

        # Setup directories
        setup_total_directories()
        
        # Start ALL tasks in parallel (don't await yet)
        total_future_lws_lslr = total_task('lws','lslr')
        total_future_lws_gslr = total_task('lws','gslr')
        total_future_sterodynamics_lslr = total_task('sterodynamics','lslr')
        total_future_sterodynamics_gslr = total_task('sterodynamics','gslr')
        total_future_all_lslr = total_task('all','lslr')
        total_future_all_gslr = total_task('all','gslr')

        results = None
        try:
            results = await asyncio.wait_for(
                asyncio.gather(
                    total_future_lws_lslr,
                    total_future_lws_gslr,
                    total_future_sterodynamics_lslr,
                    total_future_sterodynamics_gslr,
                    total_future_all_lslr,
                    total_future_all_gslr,
                    return_exceptions=True
                ),
                timeout=60  # 1 minute timeout
                # timeout=300  # 5 minute timeout
            )
            return results
        except asyncio.TimeoutError:
            logger.info("Tasks terminated after 1 minutes, but all outputs are available")
            print(results)

        logger.info(f'ALL TOTAL tasks completed for pipeline {pipeline_id}')
        logger.info(f'Climate workflow {pipeline_id} finished at {time.time()}')
        return results
        
    # Run workflow(s)
    transationId = random.randint(1, 1000)
    results = await run_total_workflow(transationId)
    logger.info(results)
    logger.info("=========Total completed successfully=========: "+ str(transationId))
    await flow.shutdown()

# %%
# Just call it with await in Jupyter
try:
    await modules()
    await total()    
except Exception as e:
    print(f"Unexpected error, RESTART kernel and re-run Notebook: {e}")
    print(f"Notebook will NOT overwrite files, so manually clean up previous runs or change directory paths if a write error occurs")
# Out:
# 2026-02-13 15:24:20.332 │ INFO │ [root] │ Logger configured successfully - Console: DEBUG, File: disabled (N/A), Structured: disabled, Style: modern
# 2026-02-13 15:24:20.332 │ INFO │ [execution.backend(concurrent)] │ ThreadPoolExecutor execution backend started successfully
# 2026-02-13 15:24:20.332 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGHUP
# 2026-02-13 15:24:20.333 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGTERM
# 2026-02-13 15:24:20.334 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGINT
# 2026-02-13 15:24:20.334 │ DEBUG │ [workflow_manager] │ Started run component
# 2026-02-13 15:24:20.335 │ INFO │ [main] │ Launching asynchronous workflow: 459
# 2026-02-13 15:24:20.335 │ INFO │ [main] │ Starting climate workflow 459 at 1771014260.3352752
# 2026-02-13 15:24:20.338 │ DEBUG │ [workflow_manager] │ Registered task: 'fair_task' with id of task.000001
# 2026-02-13 15:24:20.338 │ DEBUG │ [workflow_manager] │ Registered task: 'lws_task' with id of task.000002
# 2026-02-13 15:24:20.338 │ DEBUG │ [workflow_manager] │ Ready to submit: fair_task with resolved dependencies: []
# 2026-02-13 15:24:20.338 │ DEBUG │ [workflow_manager] │ Ready to submit: lws_task with resolved dependencies: []
# 2026-02-13 15:24:20.339 │ INFO │ [workflow_manager] │ Submitting ['fair_task', 'lws_task'] for execution
# 2026-02-13 15:24:37.900 │ INFO │ [workflow_manager] │ task.000002 is in DONE state
# 2026-02-13 15:24:46.898 │ INFO │ [workflow_manager] │ task.000001 is in DONE state
# 2026-02-13 15:24:46.898 │ INFO │ [main] │ FAIR task completed for pipeline 459
# 2026-02-13 15:24:46.899 │ DEBUG │ [workflow_manager] │ Registered task: 'sterodynamics_task' with id of task.000003
# 2026-02-13 15:24:46.899 │ DEBUG │ [workflow_manager] │ Linking implicit file(s): from fair_task to sterodynamics_task
# 2026-02-13 15:24:46.899 │ DEBUG │ [workflow_manager] │ Ready to submit: sterodynamics_task with resolved dependencies: ['fair_task']
# 2026-02-13 15:24:46.900 │ INFO │ [workflow_manager] │ Submitting ['sterodynamics_task'] for execution
# 2026-02-13 15:27:35.356 │ INFO │ [workflow_manager] │ task.000003 is in DONE state
# 2026-02-13 15:27:35.356 │ INFO │ [main] │ Climate workflow 459 finished at 1771014455.3569252
# 2026-02-13 15:27:35.357 │ INFO │ [main] │ All modules completed successfully: 459
# 2026-02-13 15:27:35.357 │ INFO │ [workflow_manager] │ Initiating shutdown
# 2026-02-13 15:27:35.357 │ DEBUG │ [workflow_manager] │ Shutting down run component
# 2026-02-13 15:27:35.357 │ DEBUG │ [workflow_manager] │ Run component cancelled
# 2026-02-13 15:27:35.358 │ INFO │ [execution.backend(concurrent)] │ Concurrent execution backend shutdown complete
# 2026-02-13 15:27:35.358 │ DEBUG │ [workflow_manager] │ Shutting down execution backend completed
# 2026-02-13 15:27:35.358 │ INFO │ [workflow_manager] │ Shutdown completed for all components.
# 2026-02-13 15:27:35.359 │ INFO │ [main] │ {'fair': 'Hello from fair-temperature!\n', 'lws': 'Hello from ssp-landwaterstorage!\n', 'sterodynamics': 'Hello from tlm-sterodynamics!\n'}
# 2026-02-13 15:27:35.359 │ INFO │ [main] │ All workflows completed successfully
# 2026-02-13 15:27:35.359 │ INFO │ [root] │ Logger configured successfully - Console: DEBUG, File: disabled (N/A), Structured: disabled, Style: modern
# 2026-02-13 15:27:35.359 │ INFO │ [root] │ Logger configured successfully - Console: DEBUG, File: disabled (N/A), Structured: disabled, Style: modern
# 2026-02-13 15:27:35.360 │ INFO │ [execution.backend(concurrent)] │ ThreadPoolExecutor execution backend started successfully
# 2026-02-13 15:27:35.360 │ INFO │ [execution.backend(concurrent)] │ ThreadPoolExecutor execution backend started successfully
# 2026-02-13 15:27:35.360 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGHUP
# 2026-02-13 15:27:35.360 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGHUP
# 2026-02-13 15:27:35.362 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGTERM
# 2026-02-13 15:27:35.362 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGTERM
# 2026-02-13 15:27:35.362 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGINT
# 2026-02-13 15:27:35.362 │ DEBUG │ [workflow_manager] │ Registered signal handler for SIGINT
# 2026-02-13 15:27:35.363 │ DEBUG │ [workflow_manager] │ Started run component
# 2026-02-13 15:27:35.363 │ DEBUG │ [workflow_manager] │ Started run component
# 2026-02-13 15:27:35.363 │ INFO │ [main] │ Starting total climate workflow 275 at 1771014455.3635907
# 2026-02-13 15:27:35.363 │ INFO │ [main] │ Starting total climate workflow 275 at 1771014455.3635907
# 2026-02-13 15:27:35.364 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_lws_lslr.nc
# 2026-02-13 15:27:35.364 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_lws_lslr.nc
# 2026-02-13 15:27:35.368 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_lws_gslr.nc
# 2026-02-13 15:27:35.368 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_lws_gslr.nc
# 2026-02-13 15:27:35.369 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/sterodynamics/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_sterodynamics_lslr.nc
# 2026-02-13 15:27:35.369 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/sterodynamics/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_sterodynamics_lslr.nc
# 2026-02-13 15:27:35.370 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/sterodynamics/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_sterodynamics_gslr.nc
# 2026-02-13 15:27:35.370 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/sterodynamics/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_sterodynamics_gslr.nc
# 2026-02-13 15:27:35.372 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/lslr.nc --item=/mnt/total_out/sterodynamics/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_all_lslr.nc
# 2026-02-13 15:27:35.372 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/lslr.nc --item=/mnt/total_out/sterodynamics/lslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_all_lslr.nc
# 2026-02-13 15:27:35.373 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/gslr.nc --item=/mnt/total_out/sterodynamics/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_all_gslr.nc
# 2026-02-13 15:27:35.373 │ INFO │ [main] │ Executing: /usr/local/other/singularity/4.0.3/bin/singularity exec --bind ./data/output:/mnt/total_in --bind ./data/output:/mnt/total_out /discover/nobackup/projects/sealevel/facts2.0/containers/sealevel-facts-total_latest-sandbox facts-total --item=/mnt/total_out/lws/gslr.nc --item=/mnt/total_out/sterodynamics/gslr.nc --pyear-start=2020 --pyear-end=2150 --pyear-step=10 --output-path=/mnt/total_out/totaled_output_all_gslr.nc
# 2026-02-13 15:28:00.510 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_lws_lslr.nc
# 2026-02-13 15:28:00.510 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_lws_lslr.nc
# 2026-02-13 15:28:00.511 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/lslr.nc
#
# 2026-02-13 15:28:00.511 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/lslr.nc
#
# 2026-02-13 15:28:00.512 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_lws_lslr.nc
#
# 2026-02-13 15:28:00.512 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_lws_lslr.nc
#
# 2026-02-13 15:28:00.518 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_lws_gslr.nc
# 2026-02-13 15:28:00.518 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_lws_gslr.nc
# 2026-02-13 15:28:00.519 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/gslr.nc
#
# 2026-02-13 15:28:00.519 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/gslr.nc
#
# 2026-02-13 15:28:00.519 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_lws_gslr.nc
#
# 2026-02-13 15:28:00.519 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_lws_gslr.nc
#
# 2026-02-13 15:28:00.521 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_sterodynamics_gslr.nc
# 2026-02-13 15:28:00.521 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_sterodynamics_gslr.nc
# 2026-02-13 15:28:00.521 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/sterodynamics/gslr.nc
#
# 2026-02-13 15:28:00.521 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/sterodynamics/gslr.nc
#
# 2026-02-13 15:28:00.522 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_sterodynamics_gslr.nc
#
# 2026-02-13 15:28:00.522 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_sterodynamics_gslr.nc
#
# 2026-02-13 15:28:00.523 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_sterodynamics_lslr.nc
# 2026-02-13 15:28:00.523 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_sterodynamics_lslr.nc
# 2026-02-13 15:28:00.523 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/sterodynamics/lslr.nc
#
# 2026-02-13 15:28:00.523 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/sterodynamics/lslr.nc
#
# 2026-02-13 15:28:00.524 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_sterodynamics_lslr.nc
#
# 2026-02-13 15:28:00.524 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_sterodynamics_lslr.nc
#
# 2026-02-13 15:28:00.667 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_all_lslr.nc
# 2026-02-13 15:28:00.667 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_all_lslr.nc
# 2026-02-13 15:28:00.668 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/lslr.nc
# - /mnt/total_out/sterodynamics/lslr.nc
#
# 2026-02-13 15:28:00.668 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/lslr.nc
# - /mnt/total_out/sterodynamics/lslr.nc
#
# 2026-02-13 15:28:00.668 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_all_lslr.nc
#
# 2026-02-13 15:28:00.668 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_all_lslr.nc
#
# 2026-02-13 15:28:00.670 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_all_gslr.nc
# 2026-02-13 15:28:00.670 │ INFO │ [main] │ Output successfully created: data/output/totaled_output_all_gslr.nc
# 2026-02-13 15:28:00.670 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/gslr.nc
# - /mnt/total_out/sterodynamics/gslr.nc
#
# 2026-02-13 15:28:00.670 │ INFO │ [main] │ Command output: Hello from FACTS totaling!
# Files to be totaled:
# - /mnt/total_out/lws/gslr.nc
# - /mnt/total_out/sterodynamics/gslr.nc
#
# 2026-02-13 15:28:00.671 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_all_gslr.nc
#
# 2026-02-13 15:28:00.671 │ WARNING │ [main] │ Command stderr: INFO:facts_total.total_workflow:Totaled projections written to /mnt/total_out/totaled_output_all_gslr.nc
#
# 2026-02-13 15:28:35.366 │ INFO │ [main] │ Tasks terminated after 1 minutes, but all outputs are available
# 2026-02-13 15:28:35.366 │ INFO │ [main] │ Tasks terminated after 1 minutes, but all outputs are available
# None
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ ALL TOTAL tasks completed for pipeline 275
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ ALL TOTAL tasks completed for pipeline 275
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ Climate workflow 275 finished at 1771014515.3674493
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ Climate workflow 275 finished at 1771014515.3674493
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ None
# 2026-02-13 15:28:35.367 │ INFO │ [main] │ None
# 2026-02-13 15:28:35.368 │ INFO │ [main] │ =========Total completed successfully=========: 275
# 2026-02-13 15:28:35.368 │ INFO │ [main] │ =========Total completed successfully=========: 275
# 2026-02-13 15:28:35.368 │ INFO │ [workflow_manager] │ Initiating shutdown
# 2026-02-13 15:28:35.368 │ INFO │ [workflow_manager] │ Initiating shutdown
# 2026-02-13 15:28:35.369 │ DEBUG │ [workflow_manager] │ Shutting down run component
# 2026-02-13 15:28:35.369 │ DEBUG │ [workflow_manager] │ Shutting down run component
# 2026-02-13 15:28:35.370 │ DEBUG │ [workflow_manager] │ Run component cancelled
# 2026-02-13 15:28:35.370 │ DEBUG │ [workflow_manager] │ Run component cancelled
# 2026-02-13 15:28:35.370 │ INFO │ [execution.backend(concurrent)] │ Concurrent execution backend shutdown complete
# 2026-02-13 15:28:35.370 │ INFO │ [execution.backend(concurrent)] │ Concurrent execution backend shutdown complete
# 2026-02-13 15:28:35.371 │ DEBUG │ [workflow_manager] │ Shutting down execution backend completed
# 2026-02-13 15:28:35.371 │ DEBUG │ [workflow_manager] │ Shutting down execution backend completed
# 2026-02-13 15:28:35.371 │ INFO │ [workflow_manager] │ Shutdown completed for all components.
# 2026-02-13 15:28:35.371 │ INFO │ [workflow_manager] │ Shutdown completed for all components.
